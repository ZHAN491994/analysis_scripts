# %%
import numpy as np
import numpy.polynomial.polynomial as poly
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import warnings
from scipy.optimize import curve_fit
from wafer_plot import draw_wafer_plot

warnings.filterwarnings('ignore')

# %%
def sin_func(x, a, b, L_pi, phi):
    return a + b * (np.sin(np.pi * x / (2 * L_pi) - phi)) ** 2

# %%
root_path = Path('/Users/jiahaozhan/Google Drive/Other Computers/CM300/Dione_wafer3_BO')
data_path = root_path / 'dcoupler_splitter_calib_test_cells_BO_wafer3'

gap_widths = np.array([0.18, 0.19, 0.2, 0.205])
lengths = np.array([1.0, 1.35, 1.7, 2.05, 2.4, 2.75, 3.1, 3.45, 3.8, 4.15, 4.5, 4.85, 5.2, 5.55, 5.9, 6.25, 6.6, 6.95, 7.3, 7.65])
print(len(lengths))
ret_num = 5

data_dir_gen = sorted(data_path.glob(f'reticle{ret_num}/*.json'))
for d in data_dir_gen:
    df = pd.read_json(d)
    ret = int(df['reticle'][0])

    wavel = df['wavelength']
    trans = df['transmission_ch1']

bar = {}
cross = {}
for i, g in enumerate(gap_widths):
    bar[g] = []
    cross[g] = []
    for j, l in enumerate(lengths):
        bar[g].append(trans[i*len(lengths)*2 + j*2][2500])  # 2500 is the index for wavelength 1310 nm
        cross[g].append(trans[i*len(lengths)*2 + j*2 + 1][2500])

print(bar)
print(cross)

dBm_to_mW = lambda p_dBm: 10 ** np.divide(np.array(p_dBm), 10)
bar_lin = {gap:dBm_to_mW(trans) for gap, trans in bar.items()}
cross_lin = {gap:dBm_to_mW(trans) for gap, trans in cross.items()}


# get a wafer plot
# draw_wafer_plot(data=losses, title=df['test_cell'][0])
# Out:
# 20
# {0.18: [-16.1785869598, -16.5653495789, -16.6814460754, -17.0341377258, -17.34333992, -17.0605201721, -16.9388866425, -16.8578872681, -16.6674633026, -16.2612514496, -15.5576314926, -15.6011371613, -14.9813833237, -14.7677211761, -14.5065803528, -14.0406551361, -13.8587627411, -13.6268463135, -13.4903383255, -13.3538513184], 0.19: [-15.7215871811, -15.9497690201, -16.328994751, -16.5808467865, -16.6908664703, -16.9144763947, -16.9035739899, -16.7667980194, -16.5753574371, -16.3197250366, -15.9746131897, -15.6468191147, -15.3483858109, -15.0818872452, -14.6148633957, -14.3650627136, -14.1591825485, -13.9828643799, -13.8080129623, -13.5868024826], 0.2: [-15.6191053391, -15.6650524139, -15.8373661041, -16.0211372375, -16.2284450531, -16.4372329712, -16.418182373, -16.3721961975, -16.2701816559, -15.9146776199, -15.8390598297, -15.7730846405, -15.3431873322, -15.056646347, -14.5609855652, -14.3918600082, -14.2311229706, -14.0905103683, -13.7278003693, -13.6084356308], 0.205: [-15.3382921219, -15.4950141907, -15.6598367691, -15.9072036743, -15.9900131226, -16.2983856201, -16.3324260712, -16.10389328, -16.1746292114, -15.8716430664, -15.8830089569, -15.7201843262, -15.3827486038, -15.1899719238, -14.6414051056, -14.5323705673, -14.2898921967, -13.9955005646, -13.7793235779, -13.4879341125]}
# {0.18: [-16.8871269226, -16.4177055359, -16.0930862427, -16.0742340088, -15.7293777466, -16.0091934204, -16.11460495, -16.1236438751, -16.3531703949, -16.552400589, -17.595703125, -17.5912265778, -18.4770584106, -18.9988994598, -19.6875114441, -22.5160198212, -23.536863327, -25.4519233704, -27.2024326324, -29.7805767059], 0.19: [-17.2970218658, -16.8686294556, -16.4943447113, -16.2469940186, -16.2024269104, -16.4113349915, -16.2546081543, -16.276758194, -16.3874130249, -16.5467300415, -17.3881225586, -17.7364730835, -18.051492691, -18.5524330139, -19.7072811127, -21.2058525085, -22.2607879639, -23.1066398621, -25.0437259674, -27.56590271], 0.2: [-17.9662036896, -17.4451084137, -16.9307689667, -16.5833473206, -16.4421691895, -16.5259208679, -16.4440135956, -16.1971740723, -16.228887558, -16.5687541962, -17.1010322571, -17.1325435638, -17.5765762329, -18.002199173, -18.8020458221, -20.1232509613, -20.7661418915, -21.380065918, -23.1049156189, -25.0238800049], 0.205: [-18.1730632782, -17.4594249725, -17.1713943481, -16.7773075104, -16.5392227173, -16.7027816772, -16.4664173126, -16.5182132721, -16.4821224213, -16.7186012268, -17.1625881195, -17.2093200684, -17.6222763062, -17.8589630127, -18.6114006042, -19.6877117157, -20.2068405151, -21.0404624939, -22.0485038757, -24.3488407135]}

# %%
colors = plt.rcParams["axes.prop_cycle"].by_key()["color"]

# make plots
fig, axes = plt.subplots(1, 4, figsize = (20, 3))
for i, g in enumerate(gap_widths):
    # fit data
    new_len = np.arange(lengths[0], lengths[-1], 0.01)
    pb_init = [0.03, 0.03/2, 4.9, 0]
    pc_init = [0.015, 0.03/2, 4.9, 0]

    x_data, y_data = lengths, bar_lin[g]
    p_opt_b, p_cov_b = curve_fit(sin_func, lengths, bar_lin[g], p0=pb_init)
    y_predicted = sin_func(lengths, *p_opt_b)
    residuals = y_data - y_predicted
    ss_total = np.sum((y_data - np.mean(y_data))**2)
    ss_residual = np.sum(residuals**2)
    r_squared_b = 1 - (ss_residual / ss_total)
    print(r_squared_b)

    x_data, y_data = lengths, cross_lin[g]
    p_opt_c, p_cov_c = curve_fit(sin_func, lengths, cross_lin[g], p0=pc_init)
    y_predicted = sin_func(lengths, *p_opt_c)
    residuals = y_data - y_predicted
    ss_total = np.sum((y_data - np.mean(y_data))**2)
    ss_residual = np.sum(residuals**2)
    r_squared_c = 1 - (ss_residual / ss_total)

    # Plot the data
    ax = axes[i]
    label_b = '$L_{\pi}$, $\phi$ = ' + f"{p_opt_b[2]:.2f}, {p_opt_b[3]/np.pi:.2f}" + '$\pi$'
    print(p_opt_b)
    ax.plot(lengths, bar_lin[g], 'o', color=colors[0], markersize=3, label=label_b)
    ax.plot(new_len, sin_func(new_len, *p_opt_b), '--', color=colors[0])

    label_c = '$L_{\pi}$, $\phi$ = ' + f"{p_opt_c[2]:.2f}, {p_opt_c[3]/np.pi:.2f}" + '$\pi$'
    print(p_opt_c)
    ax.plot(lengths, cross_lin[g], 'o', color=colors[1], markersize=3, label=label_c)
    ax.plot(new_len, sin_func(new_len, *p_opt_c), '--', color=colors[1])
    
    ax.set_xlabel('Coupling length (um)')
    ax.set_ylabel('Power (mW)')
    ax.set_title(f'reticle {ret_num}, gap = {g} um')
    # ax.set_xlim([0, 8])
    ax.set_ylim([0, 0.05])
    # ax.text(0, 0, f'$R^{2}_{bar}$ = {r_squared_b:.4f}' + '\n' + f'$R^{2}_{cross}$ = {r_squared_c:.4f}', fontsize=12)
    ax.text(1, 0.002, '$R^2_{b}$' + f' = {r_squared_b:.4f}' + '\n' + '$R^2_{c}$' + f' = {r_squared_c:.4f}')
    ax.legend()
# Out:
# 0.995502151144532
# [0.01926407 0.02806856 5.82262275 0.69753335]
# [ 2.26865567e-04  2.55218770e-02  5.55566739e+00 -8.33245302e-01]
# 0.9983309591450923
# [0.02057003 0.023974   5.53779565 0.8291684 ]
# [ 4.96773164e-04  2.36796438e-02  5.69135822e+00 -7.97930679e-01]
# 0.9903487822499659
# [0.02294783 0.02514564 6.41425695 0.73651583]
# [ 7.07860469e-04  2.28347453e-02  5.69888398e+00 -6.91627286e-01]
# 0.9928232676822667
# [0.02382321 0.03493447 7.98556594 0.62384377]
# [-3.84310011e-04  2.28833157e-02  6.20756718e+00 -7.51037760e-01]

# %%
# Wafer-level analysis for the nomial case: gap = 0.2 um, length = 3.1 um
p_current = Path().resolve().parent
root = p_current / 'results' / 'BO_wafer3_data' / 'dcoupler_splitter_calib_test_cells_BO_wafer3'

gap_widths = np.array([0.18, 0.19, 0.2, 0.205])
lengths = np.array([1.0, 1.35, 1.7, 2.05, 2.4, 2.75, 3.1, 3.45, 3.8, 4.15, 4.5, 4.85, 5.2, 5.55, 5.9, 6.25, 6.6, 6.95, 7.3, 7.65])

data_dir_gen = sorted(root.glob(f'reticle*/*.json'))
bar = {}
cross = {}

for d in data_dir_gen:
    df = pd.read_json(d)
    ret = int(df['reticle'][0])

    wavel = df['wavelength']
    trans = df['transmission_ch1']
    bar[ret] = trans[92][2500]  # i*len(lengths)*2 + j*2][2500]
    cross[ret] = trans[93][2500]

print(bar)
print(cross)

# dBm_to_mW = lambda p_dBm: 10 ** np.divide(np.array(p_dBm), 10)
# bar_lin = {gap:dBm_to_mW(trans) for gap, trans in bar.items()}
# cross_lin = {gap:dBm_to_mW(trans) for gap, trans in cross.items()}

# %%
bar_lin = {ret:10**(trans/10) for ret, trans in bar.items()}
cross_lin = {ret:10**(trans/10) for ret, trans in cross.items()}
splitting_ratio = {b_k:b_v/c_v for (b_k, b_v), (c_k, c_v) in zip(bar_lin.items(), cross_lin.items())}
print(splitting_ratio)

# get a wafer plot
draw_wafer_plot(data=splitting_ratio, title=f'Dcoupler splitting ratio \n gap = 0.2 um, length = 3.1 um')
# Out:
# {0: 1.025730451549737, 1: 0.9847530430837154, 10: 1.0125842669189529, 11: 0.9673649828873128, 12: 0.9938947420224418, 13: 1.003105445691447, 14: 0.9935783284937229, 15: 1.0547837100923116, 16: 1.1274703785134408, 17: 1.0297684053990284, 18: 0.9957188093380529, 19: 1.0674510507534822, 2: 1.0097864659493359, 20: 1.0827492061849193, 21: 1.0453188251332373, 22: 1.0367217102484843, 23: 1.05966597833813, 24: 1.0904971875808993, 25: 1.0552275905873254, 26: 1.0520709771125742, 27: 1.0893648714547879, 28: 1.0899853336006045, 29: 1.0776472274488955, 3: 0.9939792087431686, 30: 1.0895344883821203, 31: 1.099269850254756, 32: 1.1439363770518094, 33: 1.0573350924649785, 34: 1.0971438106130609, 35: 1.1705798676238093, 36: 1.1509372728439797, 37: 1.0659844600006254, 38: 1.118993963063795, 39: 1.1195469735260368, 4: 1.0574470100742805, 40: 1.137602664489246, 41: 1.166138529975117, 42: 1.1362190705075703, 43: 1.1741059752899967, 44: 1.138463828711298, 45: 1.1288894264929181, 46: 1.1524706328741725, 47: 1.1965599317613296, 48: 1.1542865947747676, 49: 1.1829577828940543, 5: 1.0059655824432652, 50: 1.2043559215063029, 51: 1.228995263229413, 52: 1.1605080341355478, 53: 1.2330360138509426, 54: 1.2360256218983643, 55: 1.2116635247080259, 56: 1.2523355768839162, 57: 1.2610885500887599, 58: 1.1945885336718878, 59: 1.2496341211274558, 6: 0.9711480070903629, 60: 1.2885368290510193, 61: 1.2593841250321791, 62: 1.3683845207346341, 63: 1.234677938204588, 7: 0.9783377586200345, 8: 0.9669211159829978, 9: 1.0416187246373125}
